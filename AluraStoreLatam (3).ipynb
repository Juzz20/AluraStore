# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head(15)
tiendas = ["tienda", "tienda2", "tienda3","tienda4"]

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %% [markdown]
# #1. Análisis de facturación

# %%
precio1 = tienda["Precio"].sum()
precio1
# Out:
# np.float64(1150880400.0)

# %%
precio2 = tienda2["Precio"].sum()
precio2
# Out:
# np.float64(1116343500.0)

# %%
precio3 = tienda3["Precio"].sum()
precio3
# Out:
# np.float64(1098019600.0)

# %%
precio4 = tienda4["Precio"].sum()
precio4
# Out:
# np.float64(1038375700.0)

# %%
mayor = max(precio1, precio2, precio3, precio4)
mayor
# Out:
# np.float64(1150880400.0)

# %%
precios=[precio1, precio2, precio3, precio4]
precios
# Out:
# [np.float64(1150880400.0),
#  np.float64(1116343500.0),
#  np.float64(1098019600.0),
#  np.float64(1038375700.0)]

# %%
plt.barh(tiendas, precios)
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda2["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda3["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda4["Categoría del Producto"].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
tienda["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %%
tienda2["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %%
tienda3["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %%
tienda4["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion = tienda["Calificación"].mean()
calificacion
# Out:
# np.float64(3.976685036032217)

# %%
calificacion2 = tienda2["Calificación"].mean()
calificacion2
# Out:
# np.float64(4.037303942348453)

# %%
calificacion3 = tienda3["Calificación"].mean()
calificacion3
# Out:
# np.float64(4.048325561678677)

# %%
calificacion4 = tienda4["Calificación"].mean()
calificacion4
# Out:
# np.float64(3.9957591178965224)

# %%
calificaciones = [calificacion, calificacion2, calificacion3, calificacion4]
plt.barh(tiendas, calificaciones)
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
ventas = tienda["Producto"].value_counts()
ventas
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
ventas.plot(kind="bar")
plt.title("Ventas por producto")
plt.xlabel("Ventas")
plt.ylabel("Producto")

plt.tight_layout()
plt.show()

# %%
ventas2 = tienda2["Producto"].value_counts()
ventas2
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# ...

# %%
ventas2.plot(kind="bar")
plt.title("Ventas por producto")
plt.xlabel("Ventas")
plt.ylabel("Producto")

plt.tight_layout()
plt.show()

# %%
ventas3 = tienda3["Producto"].value_counts()
ventas3
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# ...

# %%
ventas3.plot(kind="bar")
plt.title("Ventas por producto")
plt.xlabel("Ventas")
plt.ylabel("Producto")

plt.tight_layout()
plt.show()

# %%
ventas4 = tienda4["Producto"].value_counts()
ventas4
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# ...

# %%
ventas4.plot(kind="bar")
plt.title("Ventas por producto")
plt.xlabel("Ventas")
plt.ylabel("Producto")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio = tienda["Costo de envío"].mean()
envio
# Out:
# np.float64(26018.60958033065)

# %%
envio2 =tienda2["Costo de envío"].mean()
envio2
# Out:
# np.float64(25216.235693090293)

# %%
envio3 = tienda3["Costo de envío"].mean()
envio3
# Out:
# np.float64(24805.680373039424)

# %%
envio4 =tienda4["Costo de envío"].mean()
envio4
# Out:
# np.float64(23459.457167090754)

# %%
envios = [envio, envio2, envio3, envio4]
plt.scatter(tiendas, envios)

plt.title("Promedio de costo de envío por tienda")
plt.xlabel("Tienda")
plt.ylabel("Costo de envío promedio")
plt.grid(True)
plt.show()

# %% [markdown]
# Informe Final - Analisis de tiendas
# ##Introducción
# El propósito de este análisis es evaluar cuál de las cuatro tiendas es la mejor opción para que el Sr. Juan venda sus productos. Para llegar a una conclusión objetiva, se analizaron distintos aspectos clave del desempeño de cada tienda, incluyendo:
#
# **Ingresos totales generados.**
#
# **Categorías de productos más y menos vendidas.**
#
# **Calificaciones promedio otorgadas por los clientes.**
#
# **Productos más y menos vendidos.**
#
# **Costo de envío promedio por tienda.**
#
# A partir de estos indicadores y de las visualizaciones realizadas, se busca determinar cuál tienda ofrece las mejores condiciones para maximizar las ventas del Sr. Juan.

# %% [markdown]
# ##Analisis de Resultados
# ***Ingresos totales generados.***
#
# Luego de calcular los ingresos generados por cada tienda, se observó que:
#
# Tienda 1: 1150880400
#
# Tienda 2: 1116343500
#
# Tienda 3: 1098019600
#
# Tienda 4: 1038375700
# Conclusión de este punto: La tienda con mayores ingresos es **TIENDA 1**, lo que indica un mayor nivel de actividad y potencial de ventas. La se menor ingresos es la Tienda 4.

# %%
plt.barh(tiendas, precios)
plt.show()

# %% [markdown]
# ***Categorías de productos más y menos vendidas.***
#
# El análisis de categorías permitió identificar:
#
# Tienda 1
#
# Categoría más vendida en cada tienda: Muebles
#
# Categoría menos vendida en cada tienda: Articulos para el hogar

# %%
tienda["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# Tienda 2
#
# Categoría más vendida en cada tienda: Muebles
#
# Categoría menos vendida en cada tienda: Articulos para el hogar

# %%
tienda2["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# Tienda 3
#
# Categoría más vendida en cada tienda: Muebles
#
# Categoría menos vendida en cada tienda: Articulos para el hogar

# %%
tienda3["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# Tienda 4
#
# Categoría más vendida en cada tienda: Muebles
#
# Categoría menos vendida en cada tienda: Instrumentos Musicales

# %%
tienda4["Categoría del Producto"].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# Conclusión: La categoria mas vendida en todas las tiendas es muebles y la menos vendida es Articulos para el hogar

# %% [markdown]
# ***Calificaciones promedio otorgadas por los clientes.***
#
# Las calificaciones permiten evaluar la satisfacción del cliente:
#
# Tienda 1: 3.97
#
# Tienda 2: 4.03
#
# Tienda 3: 4.04
#
# Tienda 4: 3.99
# Conclusión de este punto: La tienda con mejor calificación en promedio es la Tienda 3, lo que indica buena atención y confianza por parte de los compradores.

# %%
plt.barh(tiendas, calificaciones)
plt.show()

# %% [markdown]
# ***Productos Más y Menos Vendidos***
#
# Tienda 1
#
# Según la cantidad de ventas por producto:
#
# Producto más vendido: Microondas,Tv y Armario
#
# Producto menos vendido: Auriculares con microfono y celular
#
# Tienda 2
#
# Según la cantidad de ventas por producto:
#
# Producto más vendido: Iniciando en programacion, microondas y bateria
#
# Producto menos vendido: Juego de mesa, mesa de comedor e impresora
#
# Tienda 3
#
# Según la cantidad de ventas por producto:
#
# Producto más vendido: Kit de bancas, mesa de comedor y cama king
#
# Producto menos vendido: Bloques de Construccion, mochila y microndas
#
# Tienda 4
#
# Según la cantidad de ventas por producto:
#
# Producto más vendido: Cama Box, cubertera y dashboard power bi
#
# Producto menos vendido: Guitarra Electrica, armario y guitarra acustica

# %% [markdown]
# ***Costo de envío promedio por tienda.***
#
# El costo de envío influye directamente en las decisiones del cliente:
#
# Tienda 1: 26018.60
#
# Tienda 2: 25216.23
#
# Tienda 3: 24805.68
#
# Tienda 4: 23459.45
# Conclusión de este punto: La tienda con menor costo de envío es la tienda 4, lo cual puede aumentar la probabilidad de compra.

# %%
plt.scatter(tiendas, envios)

plt.title("Promedio de costo de envío por tienda")
plt.xlabel("Tienda")
plt.ylabel("Costo de envío promedio")
plt.grid(True)
plt.show()

# %% [markdown]
# #Conclusion
# La tienda que muestra peor desempeño general es la **Tienda 4**, debido a los siguientes motivos:
#
# *Registra los ingresos más bajos entre todas las tiendas (1038375700), lo que evidencia menor actividad comercial y menor potencial de ventas.
#
# *Presenta una rotación de productos inferior, con varios productos en la lista de los menos vendidos (como guitarras y armarios), lo que indica poca demanda.
#
# *Su calificación promedio (3.99) es inferior a las de las tiendas 2 y 3, lo que refleja una experiencia del cliente menos positiva.
#
# *Aunque tiene el costo de envío más bajo, este factor no compensa las significativas desventajas en ventas y rendimiento general.
#
# En conjunto, estos resultados confirman que la Tienda 4 es la menos eficiente, con un desempeño inferior en los principales indicadores analizados.
